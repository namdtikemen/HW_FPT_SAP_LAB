# %% [markdown]
# <a href="https://colab.research.google.com/github/namdtikemen/HW_FPT_SAP_LAB/blob/main/Analysis_use_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/pandas_mini_project
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/pandas_mini_project'
# /content
# drive  sample_data

# %%
import csv
import pandas as pd
import numpy as np
import re

# %%
f = open('/content/drive/MyDrive/googleplaystore.csv', newline='')
with f:
  reader = csv.reader(f)
  google = list(reader)
google[10473].insert(1, 'TOOLS')  # missing 10473
data = pd.DataFrame(data=google[1:], columns=google[0])
data['Reviews'] = data['Reviews'].astype(int)
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating  Reviews                Size     Installs  Type Price  \
# 0        4.1      159                 19M      10,000+  Free     0
# 1        3.9      967                 14M     500,000+  Free     0
# 2        4.7    87510                8.7M   5,000,000+  Free     0
# 3        4.5   215644                 25M  50,000,000+  Free     0
# 4        4.3      967                2.8M     100,000+  Free     0
# ...      ...      ...                 ...          ...   ...   ...
# 10836    4.5       38                 53M       5,000+  Free     0
# 10837    5.0        4                3.6M         100+  Free     0
# 10838    NaN        3                9.5M       1,000+  Free     0
# 10839    4.5      114  Varies with device       1,000+  Free     0
# 10840    4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# **1.** In ra 5 hàng đầu tiên trong dataset.

# %%
data.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# **2.** Tính số hàng (số app), số cột (số feature mỗi app) trong dataset.

# %%
data.shape
# Out:
# (10841, 13)

# %% [markdown]
# **3.** Có nhiều app bị trùng trong dataset (ví dụ instagram) do thông tin của app được lưu nhiều lần. Tạo 1 dict key là tên app, value là số lượng reviews nhiều nhất trong các lần lưu của app đấy (group_by).

# %%
data[data.App == 'Instagram']
# Out:
#             App Category Rating   Reviews                Size        Installs  \
# 2545  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 2604  Instagram   SOCIAL    4.5  66577446  Varies with device  1,000,000,000+
# 2611  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 3909  Instagram   SOCIAL    4.5  66509917  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres   Last Updated         Current Ver  \
# 2545  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2604  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2611  Free     0           Teen  Social  July 31, 2018  Varies with device
# 3909  Free     0           Teen  Social  July 31, 2018  Varies with device
#
#              Android Ver
# 2545  Varies with device
# 2604  Varies with device
# 2611  Varies with device
# 3909  Varies with device

# %%
a = data.groupby(['App'])['Reviews'].max().to_dict()

# %%
a
# Out:
# {'"i DT" Fútbol. Todos Somos Técnicos.': 27,
#  '+Download 4 Instagram Twitter': 40467,
#  '- Free Comics - Comic Apps': 115,
#  '.R': 259,
#  '/u/app': 573,
#  '058.ba': 27,
#  '1. FC Köln App': 2019,
#  '10 Best Foods for You': 2490,
#  '10 Minutes a Day Times Tables': 681,
#  '10 WPM Amateur ham radio CW Morse code trainer': 10,
#  '10,000 Quotes DB (Premium)': 70,
#  '100 Doors of Revenge': 105766,
#  '100+ C Programs': 20,
#  '100000+ Messages - DP, Status, Jokes & GIF 2018': 121,
#  '101 C Programming Problems': 498,
#  '104 Looking for a job - looking for a job, looking for a job, looking for a part-time job, health checkup, resume, treatment room': 74359,
#  '11st': 48732,
#  '12 Step Meditations & Sober Prayers AA NA AL-ANON': 759,
#  '14thStreetVet': 0,
#  '17th Edition Cable Sizer': 47,
#  '1800 Contacts - Lens Store': 23160,
#  '1LINE – One Line with One Touch': 214878,
#  '1st Fed CI Mobile Banking': 0,
#  '2 Amateur ham radio CW Morse code practice keys TX': 6,
#  '2-Player Co-op Zombie Shoot': 33,
#  '20 Minuten (CH)': 14153,
#  '20 minutes (CH)': 4379,
#  '2000 AD Comics and Judge Dredd': 705,
#  '2017 BN SM Sales Conference': 2,
#  '2017 EMRA Antibiotic Guide': 12,
#  '2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif': 115773,
#  '2019 Tricks Es File Explores': 4,
#  '2048 BTS J Hope KPop Puzzle Game': 17,
#  '2048(AI)': 20,
#  '20WPM Amateur ham radio Koch CW Morse code trainer': 12,
#  '21-Day Meditation Experience': 11506,
#  '211:CK': 8,
#  '211:CK Lite': 3,
#  '23rd QM BDE EO': 0,
#  '24 megapixel hd camera': 802,
#  '24/7 BZ Reis': 421,
#  '25 Mins Ako ay may lobo Etc Pinoy Kid Song Offline': 0,
#  '25WPM Amateur ham radio Koch CW Morse code trainer': 0,
#  '2Date Dating App, Love and matching': 41605,
#  '2Do - Reminders, To-do List & Notes': 4649,
#  '2GIS: directory & navigator': 768833,
#  '2RedBeans': 337,
#  '2ndLine - Second Phone Number': 15880,
#  '30 Day AB Challenge - Lumowell': 793,
#  '30 Day Ab Challenge': 1886,
#  '30 Day Ab Challenge FREE': 48253,
#  '30 Day Fitness Challenge - Workout at Home': 471036,
#  '30-Day Ab Challenge Tracker': 224,
#  '30WPM Amateur ham radio Koch CW Morse code trainer': 1,
#  '350 Diy Room Decor Ideas': 27,
#  '360 Security - Free Antivirus, Booster, Cleaner': 16771865,
#  '360-M Flight': 84,
#  '365Scores - Live Scores': 666521,
#  '3D Blue Glass Water Keyboard Theme': 62209,
#  '3D Bowling': 1076243,
#  '3D Color Pixel by Number - Sandbox Art Coloring': 1518,
#  '3D Color by Number with Voxels': 5481,
#  '3D Color by Number: Voxel, Unicorn, Pixel Art 3D': 2017,
#  '3D DJ – DJ Mixer 2018': 6333,
#  '3D DJ – Music Mixer with Virtual DJ': 796,
#  '3D Holograms Joke': 31596,
#  '3D Live Neon Weed Launcher': 1724,
#  '3D Metal Piano Keys Keyboard Theme': 467,
#  '3D Tennis': 1008012,
#  '3DAnimeGirl DX DreamPortrait KAWAII Girl DressUp': 449,
#  '3G DZ Configuration': 488,
#  '3G to 4G Converter - Simulator': 268,
#  '3G/4G Config Dz': 2058,
#  '4 Paws PH': 1,
#  '4 in a Row': 4257,
#  '4 in a row': 47698,
#  '4 x4 Offroad SUV 3D Truck Simulator Driving 2017': 32,
#  "4-T's Bar-BQ & Catering": 0,
#  '420 BZ Budeze Delivery': 2,
#  '4Eternity EO': 0,
#  '4K Ultra Camera': 382,
#  '4K VIDEO PLAYER ULTRA HD': 20,
#  '4K Wallpapers and Ultra HD Backgrounds': 7583,
#  '4x4 Jeep Racer': 7279,
#  '5 Minute Ab Workouts': 2067,
#  '5 Minute Clinical Consult 2019 - #1 for 25 years': 33,
#  '5 Minute Veterinary Consult: Canine & Feline': 17,
#  '5 Nights at Cube Pizzeria City': 2691,
#  '5-Minute Clinical Consult': 84,
#  '50 Healthy Slow Cooker Recipes': 196,
#  '500 AP World History Questions': 7,
#  '50000 Free eBooks & Free AudioBooks': 52312,
#  '591 Housing Trading - Hong Kong': 3522,
#  '591 housing transactions - renting houses, middle-class houses, new cases, real-time registration, villas through the sky, apartment suites, MRT, buying a house selling prices, housing mortgages': 24977,
#  '6 Pack Promise - Ultimate Abs': 18921,
#  '7 Cups: Anxiety & Stress Chat': 13799,
#  '7 Day Food Journal Challenge': 3346,
#  '7 Minute Workout': 399009,
#  '7 Nights at Pixel Pizzeria - 2': 23168,
#  '7 Weeks - Habit & Goal Tracker': 6011,
#  '7 minute abs workout - Daily Ab Workout': 527,
#  '8 Ball Pool': 14201891,
#  '850 Sports News Digest': 539,
#  '8fit Workouts & Meal Planner': 115721,
#  '95Live -SG#1 Live Streaming App': 4954,
#  '98point6': 47,
#  '9GAG: Funny Gifs, Pics, Memes & Videos for IGTV': 1450632,
#  '9th stage': 454,
#  'A & B Taxi': 41,
#  'A Better Camera': 76484,
#  'A Call From Santa Claus!': 3720,
#  'A Manual of Acupuncture': 214,
#  'A Word A Day': 2398,
#  'A hundred': 236,
#  'A&E - Watch Full Episodes of TV Shows': 29708,
#  'A&W Restaurants': 14,
#  'A+ Gallery - Photos & Videos': 223941,
#  'A+ Mobile': 730,
#  'A-B repeater': 32,
#  'A-J Media Vault': 1,
#  'A-Y Collection': 2,
#  'A-Z App Store': 2728,
#  'A-Z Punjabi Songs & Music Videos 2018': 367,
#  'A-Z Screen Recorder -': 17,
#  'A. O. Smith': 32,
#  'A.J. Green Wallpapers 4 Fans': 0,
#  'A.J. Styles HD Wallpapers 2018': 1,
#  'A/C Air Conditioner Remote': 7816,
#  'A/C REFRIGERANT CAPACITY': 84,
#  'A/C Universal Remote Control': 3263,
#  'A41 WatchFace for Android Wear Smart Watch': 231,
#  'AAFP': 63,
#  'AAS-IN-ASIA 2018': 3,
#  'AB Anywhere Mobile Banking': 3,
#  'AB Blast Match 3': 111,
#  'AB Click2Shop': 454,
#  'AB Crush Match 3': 96,
#  'AB Match': 9,
#  'AB Mobile App': 2105,
#  'AB Repeat Player': 1628,
#  'AB Screen Recorder': 533,
#  'ABAI CE Scanner': 0,
#  'ABC Kids - Tracing & Phonics': 36606,
#  'ABC News - US & World News': 18976,
#  'ABC Preschool Free': 27572,
#  'ABC – Live TV & Full Episodes': 50428,
#  'ABC15 Arizona': 1820,
#  'ABCmouse.com': 50887,
#  'ABG Master': 2,
#  'ABS Workout - Belly workout, 30 days AB': 5103,
#  'ABTO CY-ET1': 1,
#  'AC & TV, DVD, Set Top Box - Remote control IR': 3632,
#  'AC - Tips & News for Android™': 23292,
#  'AC Air condition Troubleshoot,Repair,Maintenance': 27,
#  'AC CE BJT Actorial': 1,
#  'AC DC Power Monitor': 1,
#  'AC Freedom': 537,
#  'AC Mobile Control': 1450,
#  'AC REMOTE UNIVERSAL-PRO': 402,
#  'AC Remote Control': 472,
#  'AC Remote Control Simulator': 353,
#  'AC Remote For LG': 1298,
#  'AC Remote for Carrier - NOW FREE': 163,
#  'AC Remote for Daikin - NOW FREE': 383,
#  'AC Remote for Haier - NOW FREE': 336,
#  'AC Remote for LG - NOW FREE': 1041,
#  'AC Remote for Midea - NOW FREE': 448,
#  'AC Remote for O General - NOW FREE': 274,
#  'AC Remote for Samsung - NOW FREE': 566,
#  'AC Remote for Sharp - NOW FREE': 332,
#  'AC Troubleshooter': 147,
#  'AC WIFI': 41,
#  'AC remote control mobile': 3043,
#  'AC-BL': 0,
#  'ACCDB MDB DB Manager Pro - Editor for MS Access': 19,
#  'ACCEPT CE MARKING': 0,
#  'ACE Elite': 2898,
#  'ACTIVEON CX & CX GOLD': 439,
#  'AD - News, Sports, Region & Entertainment': 10382,
#  'AD - Nieuws, Sport, Regio & Entertainment': 10369,
#  'ADMIRALTY H-Note': 176,
#  'ADP Mobile Solutions': 85185,
#  'ADS-B Driver': 2,
#  'ADW Launcher 2': 181399,
#  'ADWLauncher 1 EX': 28728,
#  'AE + Aerie: Jeans, Dresses, Swimsuits & Bralettes': 20476,
#  'AE 3D MOTOR :Racing Games Free': 74902,
#  'AE 3D Moto 3': 2588,
#  'AE Air Hockey': 926,
#  'AE Angry Chef': 533,
#  'AE Archer': 8638,
#  'AE Basketball': 8100,
#  'AE Bingo: Offline Bingo Games': 61746,
#  'AE Blackjack': 1417,
#  'AE Bubble:Offline Bubble Games': 6973,
#  'AE Bulletins': 14,
#  'AE Checkout Plugin': 208,
#  'AE City Jump': 804,
#  'AE Coin Mania : Arcade Fun': 30002,
#  'AE Fishing Hunter': 14,
#  'AE FreeCell': 358,
#  'AE GTO Racing': 6988,
#  'AE Garage': 64,
#  'AE Gun Ball: arcade ball games': 8581,
#  'AE Jewels': 960,
#  'AE Jewels 2: Island Adventures': 652,
#  'AE Lucky Fishing': 18277,
#  'AE Manager': 0,
#  'AE Master Moto': 17876,
#  'AE Order': 19,
#  'AE Roundy POP': 5262,
#  'AE Solitaire': 1776,
#  'AE Spider Solitaire': 17263,
#  'AE Sudoku': 2171,
#  'AE Video Poker': 721,
#  'AEE AP': 4,
#  "AEMET's time": 15966,
#  'AF Comics Reader - Free': 5,
#  'AF Hydro': 136,
#  'AF Johannesburg': 3,
#  'AF Legendary 2017': 0,
#  'AF Link': 210,
#  'AF Nutrition - Integratori': 6,
#  'AF Our Time to Shine': 0,
#  'AF-STROKE': 5,
#  'AF-STROKE (FREE)': 93,
#  'AG Contacts, Lite edition': 185,
#  'AG Contacts, Premium edition': 88,
#  'AG Drive 3D': 164,
#  'AG EMS Tour': 3,
#  'AG Fast Service Automotive': 5,
#  'AG Screen Recorder': 7,
#  'AG Subway Simulator Lite': 6738,
#  'AG Subway Simulator Mobile': 623,
#  'AG Subway Simulator Pro': 0,
#  'AG Track': 12,
#  'AG test': 3,
#  'AH Alarm Panel': 7,
#  'AH Connect (Adventist Health)': 5,
#  'AH Kollection for KLWP': 644,
#  'AH Lake Villa': 3,
#  'AH of Rocky Hill': 0,
#  'AH! Soundboard': 11,
#  'AH-1 Viper Cobra Ops - helicopter flight simulator': 1088,
#  'AI Benchmark': 97,
#  'AI Draw | Art Filter for Selfie': 20,
#  'AI Face Beauty Analysis - IntelliFace (Free)': 40,
#  'AI Image Recognizer (beta)': 0,
#  'AI Sight': 43,
#  'AI Today : Artificial Intelligence News & AI 101': 43,
#  'AI with Python Tutorial': 8,
#  'AJ AUTO': 0,
#  'AJ Academy: Amazing Animals': 1564,
#  'AJ Bell Youinvest': 135,
#  'AJ Blue Icon Pack': 4,
#  'AJ Cam': 44,
#  'AJ Concept Group App': 0,
#  'AJ Gray Dark Icon Pack': 2,
#  'AJ Gray Icon Pack': 5,
#  'AJ Jump: Animal Jam Kangaroos!': 2975,
#  "AJ Men's Grooming": 2,
#  'AJ Nails Supply': 1,
#  'AJ Official': 31,
#  'AJ Orange Icon Pack': 0,
#  'AJ Percent Off Calculator': 134,
#  'AJ Player': 18,
#  'AJ RETAILS': 9,
#  'AJ Rafael Music Lessons': 1,
#  'AJ Rafael Music Lyrics': 0,
#  'AJ Reminders': 0,
#  'AJ Styles HD Wallpapers': 48,
#  'AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper': 18,
#  'AJ Tracey Music and Lyrics': 0,
#  'AJ Turquoise Dark Icon Pack': 0,
#  'AJ Wallpapers': 0,
#  'AJ and Alyssa': 0,
#  'AJ+ Beta': 0,
#  'AJ-COMICS': 0,
#  'AJ렌터카 법인 카셰어링': 0,
#  'AK 47 Assault Rifle Wallpapers': 1,
#  'AK 47 Guns Wallpaper': 322,
#  'AK 47 Live Wallpaper': 585,
#  'AK 47 Lock Screen': 5,
#  'AK Blackjack': 4,
#  'AK Booster': 71,
#  'AK Interactive': 734,
#  'AK Lodi Films': 23,
#  'AK Math Coach': 283,
#  'AK Phone': 9,
#  'AK-47 3D': 91,
#  'AK-47 Assault Rifle': 165,
#  'AK-47 Assult Rifle: Gun Shooting Simulator Game': 1,
#  'AK-47 Simulation and Info': 2,
#  'AK-47 Sounds': 656,
#  'AK-47 guns Sounds': 2,
#  'AK-47 sounds': 7,
#  'AK-47: Simulator and Shooting': 345,
#  'AK47 Assault Rifle': 54,
#  'AKASO DV': 99,
#  'AL Voice Recorder': 4832,
#  'AL.com': 803,
#  'AL.com: Alabama Football News': 459,
#  'ALL-IN-ONE PACKAGE TRACKING': 167406,
#  'ALPHA - Artificial Intelligence': 51,
#  'AMBW Dating App: Asian Men Black Women Interracial': 2,
#  'AMC': 20843,
#  'AMC Theatres': 44550,
#  'AMM Events & CPD': 5,
#  'AND CO': 175,
#  'AO Player': 9,
#  'AO Surgery Reference': 2570,
#  'AO-EVENT': 0,
#  'AO/OTA Fracture Classification': 25,
#  'AOL - News, Mail & Video': 62465,
#  'AP App for Android™': 188,
#  'AP Art History Flashcards': 1,
#  'AP Biology Prep: Practice Tests, Flashcards': 87,
#  'AP Biology Study Guide + Quiz': 105,
#  'AP Calculus BC Practice Test': 4,
#  'AP Calculus BC: Practice Tests and Flashcards': 5,
#  'AP Chemistry Prep: Practice Tests and Flashcards': 55,
#  'AP ENPS Mobile': 22,
#  'AP English Language: Practice Tests and Flashcards': 19,
#  'AP European History: Practice Tests and Flashcards': 7,
#  'AP Flashcards': 88,
#  'AP Government Review': 3,
#  'AP Installer': 23,
#  'AP Manager': 177,
#  'AP Math & Computer Science': 37,
#  'AP Mobile': 117,
#  'AP Mobile - Breaking News': 76677,
#  'AP Mobile 104': 0,
#  'AP Physics 1 Prep: Practice Tests and Flashcards': 29,
#  'AP Planner': 45,
#  'AP Psychology Prep: Practice Tests and Flashcards': 242,
#  'AP Series Solution Pro': 0,
#  'AP Stamps and Registration': 82,
#  'AP Statistics Prep: Practice Tests and Flashcards': 19,
#  'AP Themes for Kustom/KLWP': 5,
#  'AP World History: Practice Tests and Flashcards': 21,
#  'APE Weather ( Live Forecast)': 20008,
#  'APN Settings': 3743,
#  'APOEL FC': 688,
#  'APUS Booster - Space Cleaner & Booster': 1048766,
#  'APUS File Manager (Explorer)': 498894,
#  'APUS Launcher - Theme, Wallpaper, Hide Apps': 5783441,
#  'APagri CD': 5,
#  'AP® Guide': 3,
#  'AQ Aspergers Test': 265,
#  'AQ Coach': 0,
#  'AQ Dentals': 0,
#  'AQ Guards': 0,
#  'AQ Math Facts': 1,
#  'AQ Ria Retail': 4,
#  'AQ SMS Notify': 0,
#  'AQ Service': 4,
#  'AQ wisdom +': 0,
#  'AQ: First Contact': 0,
#  'AR Dragon Pet': 0,
#  'AR Remote Car': 1354,
#  'AR Sport Cars': 284,
#  'AR Tank Battle': 153,
#  'AR Toybox - Augmented Reality Demos': 20,
#  'AR Toys: Playground Sandbox | Remote Car': 153,
#  'AR effect': 79792,
#  'ARK: Survival Evolved': 51523,
#  'ARY NEWS': 2959,
#  'ARY NEWS URDU': 1071,
#  'ARuler - AR Ruler app, Measure tools': 1602,
#  'AS - Diario online deportivo. Fútbol, motor y más': 0,
#  'AS - News and sports results.': 20879,
#  'AS Guía de las Ligas 2017-2018': 4374,
#  'ASCCP Mobile': 63,
#  'ASCP® CG Exam Flashcards 2018': 0,
#  'ASOS': 181823,
#  'ASRA Coags': 15,
#  'ASUS Calling Screen': 102451,
#  'ASUS Cover for ZenFone 2': 43960,
#  'ASUS Gallery': 125259,
#  'ASUS PixelMaster Camera': 626366,
#  'ASUS Quick Memo': 23089,
#  'ASUS Sound Recorder': 34126,
#  'ASUS SuperNote': 26559,
#  'AT&T Call Protect': 6454,
#  'AT&T Digital Life': 10067,
#  'AT&T DriveMode': 8465,
#  'AT&T FamilyMap®': 21592,
#  'AT&T Messages for Tablet': 3044,
#  'AT&T Mobile Transfer': 22775,
#  'AT&T Navigator: Maps, Traffic': 32862,
#  'AT&T Smart Limits℠': 2300,
#  'AT&T Smart Wi-Fi': 18513,
#  'AT&T THANKS®': 2445,
#  'AT&T U-verse': 38606,
#  'AT&T Visual Voicemail': 13761,
#  'ATC Unico BS': 10,
#  'ATI Cargoes and Transportation': 4162,
#  'AU Call Blocker - Block Unwanted Calls Texts 2018': 16,
#  'AU Mobile Indonesia': 16521,
#  'AU Results - AU COE Corner': 664,
#  'AU Results 2017 Auzone': 762,
#  'AU Spark': 681,
#  'AU Students Zone (Result 2016)': 97,
#  "AV Anthony's": 0,
#  'AV Buddy Free': 25,
#  'AV HD Video Player': 6,
#  'AV High School District': 91,
#  'AV MAX': 9,
#  'AV Phone': 4,
#  'AV Phonetics': 259,
#  'AV Pro Voice Changer': 174,
#  'AV Tools': 631,
#  'AV Tools Pro': 35,
#  'AV-IPTV': 43,
#  'AVG AntiVirus 2018 for Android Security': 6207063,
#  'AVG Cleaner – Speed, Battery & Memory Booster': 1188154,
#  'AW': 0,
#  'AW - Le News di AndroidWorld': 2808,
#  'AW - free video calls and chat': 7317,
#  'AW Browser with Chrome Custom Tabs': 9,
#  'AW CAMERA': 2,
#  'AW Connect': 0,
#  'AW Radio': 1,
#  'AW Reader: news & apps [Dutch]': 1948,
#  'AW Screen Recorder No Root': 1659,
#  'AW TeamUp': 9,
#  'AW Toolbox': 3,
#  'AW Tozer Devotionals - Daily': 8,
#  'AW Training': 11,
#  'AX Battery Saver': 4546,
#  'AX Player -Nougat Video Player': 15765,
#  'AX Selfie': 10,
#  'AX Timesheets App for Dynamics': 0,
#  'AX Video Player': 569,
#  'AX Watch for WatchMaker': 2,
#  'AX Window': 0,
#  'AX!OM': 5,
#  'AX-PIC Pedidos': 1,
#  'AXE.IO - Brutal Survival Battleground': 3845,
#  'AY EMLAK': 8,
#  'AY Oakmont': 0,
#  'AY Recorder - Screen Recorder, Live, Video Editor': 12,
#  'AY Recruitment': 1,
#  'AY Sing': 111,
#  'AZ Browser. Private & Download': 1520,
#  'AZ Camera - Manual Pro Cam': 2332,
#  'AZ Immune Related AEManagement': 3,
#  'AZ Lottery Players Club': 97,
#  'AZ Mobile Gizmo': 16,
#  'AZ PLAYER HD': 24,
#  'AZ Plugin 2 (newest)': 11087,
#  'AZ Practice Test & Questions': 13,
#  'AZ REMOTE CONTROL': 149,
#  'AZ Rockets': 162,
#  'AZ Screen Recorder - No Root': 751911,
#  'AZ Screen Recorder pro': 60,
#  'Aab e Hayat Full Novel': 1476,
#  'Aaj Bangla: ei samay er khobor': 34,
#  'Ab Workouts': 27501,
#  'Ab Workouts - Ab Generator': 21,
#  'Abdominal CT Sectional Walker': 2,
#  'Ability DS UNO': 3,
#  'Abs Training-Burn belly fat': 2071,
#  'Abs Workout - 30 Days Fitness App for Six Pack Abs': 299,
#  'Abs Workout - Burn Belly Fat with No Equipment': 69279,
#  'Abs workout - 21 Day Fitness Challenge': 18604,
#  'Abs workout 7 minutes': 37224,
#  'Abs, Core & Back Workout Challenge': 3908,
#  'Absolute RC Heli Simulator': 654,
#  'Ac remote control': 822,
#  'AcDisplay': 66473,
#  'Access Point Browser': 25,
#  'Access Point Finder': 22,
#  'Access Point Names': 138,
#  'Access Point Proximity': 5,
#  'Account Class-11 Solutions (D K Goel)': 663,
#  'Account Class-12 Solutions (D K Goel) Vol-1': 708,
#  'Account Class-12 Solutions (D K Goel) Vol-2': 124,
#  'Account Manager': 76604,
#  'Accounting App - Zoho Books': 3079,
#  'Accounting Quiz (AQ) Malaysia': 25,
#  'AccuWeather: Daily Forecast & Live Weather Reports': 2053404,
#  'Ace Screen Recorder w facecam': 2447,
#  'Acorn TV: World-class TV from Britain and Beyond': 493,
#  'Acorns - Invest Spare Change': 45962,
#  'Across Age DX': 5964,
#  'ActionDirector Video Editor - Edit Videos Fast': 74531,
#  'Active Soccer 2 DX': 28,
#  'Acupuncture Assistant': 492,
#  'Ad Block REMOVER - NEED ROOT': 999,
#  'Ad Blocker Turbo - Adblocker Browser': 107,
#  'Ad Blocker for SayHi': 4,
#  'Ad Detect Plugin - Handy Tool': 5107,
#  'Ad Detector': 208,
#  'Ad Removal: thereisonlywe': 16,
#  'Ad Remove Plugin for App2SD': 66,
#  'Ad-free Triangle Solver': 118,
#  'AdClear Ad blocker for Samsung': 1586,
#  'AdWords Express': 7149,
#  'Ada - Your Health Guide': 87418,
#  'Adblock Browser for Android': 121113,
#  'Adblock Fast': 9914,
#  'Adblock Plus for Samsung Internet - Browse safe.': 8769,
#  'Add Text To Photo': 21578,
#  'Add Watermark Free': 18325,
#  'Add-On: Alcatel (h)': 107,
#  'Add-On: bq (a)': 26,
#  'Add-On: bq (b)': 9,
#  'Add-On: bq (c)': 17,
#  'Adguard Content Blocker': 14491,
#  'Adhenarcos - Coupe Adhemar EY 2018': 0,
#  'Adivina el Emoji': 2536,
#  'Adivina el cantante de Trap y Reggaeton': 1914,
#  'Adobe Acrobat Reader': 3016305,
#  'Adobe Fill & Sign: Easy PDF Form Filler': 11402,
#  'Adobe Illustrator Draw': 65766,
#  'Adobe Photoshop Express:Photo Editor Collage Maker': 914917,
#  'Adobe Photoshop Fix': 28390,
#  'Adobe Premiere Clip': 39495,
#  'Adult Color By Number Book: Number Coloring Pages': 2231,
#  'Adult Color by Number Book - Paint Mandala Pages': 997,
#  'Adult Dating - AdultFinder': 1601,
#  'Adult Dirty Emojis': 80,
#  'Adult Glitter Color by Number Book - Sandbox Pages': 8918,
#  'Advanced Comprehension Therapy': 3,
#  'Advanced Download Manager': 569727,
#  'Advanced Download Manager Holo': 16192,
#  'Advanced Download Manager Pro': 6505,
#  'Advanced EX for FIAT': 138,
#  'Advanced EX for HYUNDAI': 168,
#  'Advanced EX for KIA': 257,
#  'Advanced EX for MITSUBISHI': 33,
#  'Advanced EX for NISSAN': 164,
#  'Advanced EX for RENAULT': 130,
#  'Advanced Task Killer': 577059,
#  'Advanced Warfare Guns': 2079,
#  'Advanced calculator fx 991 es plus & 991 ms plus': 7252,
#  'Adventure Quest World Mobile Quiz': 28,
#  'Adventure Time Game Wizard': 4107,
#  'Adventure Time Run': 24628,
#  'Adventure Xpress': 24775,
#  'AdventureQuest 3D MMO': 22667,
#  'AdventureQuest Dragons': 10114,
#  'Ae Allah na Dai (Rasa)': 263,
#  'Aegis BT': 16,
#  'AfreecaTV': 381023,
#  'AfterFocus': 165224,
#  'Afterlight': 50893,
#  'Ag Across America': 0,
#  'Ag Guardian': 1,
#  'Ag PhD Deficiencies': 20,
#  'Ag PhD Field Guide': 114,
#  'Ag PhD Planting Population Calculator': 0,
#  'Ag PhD Soils': 3,
#  'Ag PhD Soybean Diseases': 0,
#  'Ag Tools': 2,
#  'Ag Trucking Mobile App': 0,
#  'Ag Valley Cooperative': 6,
#  'Ag Weather Tools': 0,
#  'Ag-Power': 0,
#  'Ag-Pro Companies': 0,
#  'Agar.io': 3816799,
#  'Age Calculator': 24265,
#  'Age of AI: War Strategy': 71,
#  'Age of Conquest: N. America': 659,
#  'Age of Procreation DX': 1894,
#  'Agenda EF': 79,
#  'Agent HQ for The Division': 1060,
#  'Agoda – Hotel Booking Deals': 263525,
#  'Ah !': 3,
#  'Ah Bailar': 10,
#  'Ah Ha Block': 2,
#  'Ah! Bird': 1689,
#  'Ah! Coins': 256,
#  'Ah! Cutie': 536,
#  'Ah! Monster': 1998,
#  'Ai File Viewer': 66,
#  'Ai La Trieu Phu - ALTP Free': 776,
#  'Ai illustrator viewer': 486,
#  'Ai-Ball AV Recorder': 90,
#  'Ain Arabic Kids Alif Ba ta': 0,
#  'Air Conditioner Maintenance': 11,
#  'Air Traffic': 14110,
#  'Air Transat CinePlus B': 83,
#  'Air conditioner remote control': 29854,
#  'AirAsia': 98585,
#  'AirWatch Agent': 20973,
#  'AirWatch Inbox': 8346,
#  'Airbnb': 359560,
#  'Airplane Fly Hawaii': 83427,
#  'Airplane Pilot Car Transporter': 182363,
#  'Airport + Flight Tracker Radar': 6762,
#  'Airway Ex - Intubate. Anesthetize. Train.': 123,
#  'Aj Di Awaaz': 9,
#  'Aj. Vallbona': 0,
#  'Aj.Petra': 5,
#  'Ak Parti Yardım Toplama': 0,
#  'Ak-47 Wallpapers 2018': 7,
#  'Akinator': 1805398,
#  'Ako ay may lobo Pinoy Kid Song Offline': 0,
#  'Al Jazeera English': 24456,
#  'Al Mayadeen': 13620,
#  'Al Quran (Tafsir & by Word)': 57400,
#  'Al Quran : EAlim - Translations & MP3 Offline': 96419,
#  'Al Quran Al karim': 41608,
#  'Al Quran Audio (Full 30 Juz)': 7878,
#  'Al Quran Free - القرآن (Islam)': 1777,
#  'Al Quran Indonesia': 445756,
#  'Al Quran MP3 - Quran Reading®': 47463,
#  'Al jazeera TV': 9952,
#  "Al'Quran Bahasa Indonesia": 361780,
#  "Al'Quran Bahasa Indonesia PRO": 1340,
#  'Al-Moazin Lite (Prayer Times)': 284670,
#  'Al-Muhaffiz': 2319,
#  'Al-Quran (Free)': 218451,
#  'Al-Quran 30 Juz free copies': 12322,
#  'Al-Quran Ahmad Saud Offline': 7116,
#  'Al-Quran Al-Muallim': 199,
#  'AlReader -any text book reader': 90468,
#  'Alabama Ag Credit Ag Banking': 0,
#  'Alabama DMV Permit Test - AL': 218,
#  'Alabama Gameday Live': 19,
#  'Alabama Road Trips': 71,
#  'Alachua County Sheriff FL': 5,
#  'Alarm Clock': 114788,
#  'Alarm Clock Free': 59973,
#  'Alarm Clock Plus★': 155693,
#  'Alarm Clock: Stopwatch & Timer': 870928,
#  'Alarm.fo – choose your info': 19,
#  'Alarmy (Sleep If U Can) - Pro': 10249,
#  'Alba Heaven - Alvarez Job Portal Services': 8941,
#  'Alchemy Classic Ad Free': 20178,
#  'Aldiko Book Reader': 210534,
#  'Alerte au gogol': 14,
#  'Alex & Co Quiz': 9,
#  'Alex Fuel Calculator for EK': 19,
#  'Alfa-Bank (Alfa-Bank)': 44545,
#  'Alfred Home Security Camera': 103305,
#  "Ali Baba's Farm Tutorial Kids Games": 36,
#  'AliExpress - Smarter Shopping, Better Living': 5917485,
#  'Alif Ba Ta Bullseye': 1,
#  'Alif Ba Ta Song - Arabic Kids': 227,
#  'Alipay': 42497,
#  'Alizay, pirate girl': 197,
#  'All AJK Board Matric Fa Fsc Results': 0,
#  'All C Programs': 2387,
#  'All Email Providers': 20901,
#  'All Events in City': 3782,
#  'All Football - Latest News & Videos': 152867,
#  'All Football GO- Live Score, Games': 1981,
#  'All Info about Cg': 15,
#  'All Language Translator': 29944,
#  'All Language Translator Free': 30105,
#  'All Maths Formulas': 2709,
#  'All Mental disorders': 453,
#  'All Social Networks': 22650,
#  'All Star Of CW': 0,
#  'All States Ag Parts': 68,
#  'All Type Ac Repair & Services': 45,
#  'All Type DP': 1853,
#  'All Types DP & Status Maker': 16,
#  'All Video Downloader': 165723,
#  'All Video Downloader 2018': 7557,
#  'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)': 1754,
#  'All-In-One Toolbox: Cleaner, Booster, App Manager': 536926,
#  'All-in-One Mahjong 3': 38,
#  'All-in-One Mahjong 3 FREE': 566,
#  'All-night drugstore CI & Price': 0,
#  'AllTrails: Hiking, Running & Mountain Bike Trails': 16943,
#  'Allegiant': 5572,
#  'Allrecipes Dinner Spinner': 61881,
#  'Allsetra B.V.': 15,
#  'Alopec - Online Shipping System': 1240,
#  'Alpha Bank CY': 39,
#  'Alphabet "H" Passcode Lock Screen': 2,
#  'Alphabet A-Z': 306,
#  'Alt-C': 499,
#  "Alto's Adventure": 515657,
#  'Alumni BJ': 2,
#  'Alzashop.com': 32014,
#  'Amadeus GR & CY': 4,
#  'Amazing CG Backgrounds': 34,
#  'Amazing Fart Sounds': 28136,
#  'Amazon Drive': 18669,
#  'Amazon FreeTime – Kids’ Videos, Books, & TV shows': 2715,
#  'Amazon Kindle': 814151,
#  'Amazon Prime Video': 411683,
#  'Amazon Shopping': 909226,
#  'Amazon for Tablets': 141613,
#  'Amber Weather': 260137,
#  'Ambient CX': 0,
#  'Ambulance Rescue Simulator 17': 6669,
#  'Ambulance Simulator 3D': 29415,
#  'American Airlines': 16980,
#  'American Girls Mobile Numbers': 5,
#  'American Muscle Car Race': 129,
#  'American Sniper City Fight Shooting Assassin': 395,
#  'Amex Mobile': 24729,
#  'Amino: Communities and Chats': 1264084,
#  'Amleen Ey': 0,
#  'Amtrak': 16815,
#  'An Elite Warrior Ex': 15,
#  'Analog BW - Camera filter effect foto film retouch': 2,
#  'Analog Clock AW Plus-7': 725,
#  'Analog Clock AW-7': 2158,
#  'Analog Clock AW-7 PRO': 40,
#  'Analog and Digital Clock AW-7': 202,
#  'Analog and Digital Clock AW-7PRO': 4,
#  'Anatomy & Physiology Vocabulary Exam Review App': 1,
#  'Anatomy Learning - 3D Atlas': 72167,
#  'AnatomyMapp': 80,
#  'Ancestry': 64513,
#  'AndStream - Streaming Download': 38607,
#  'AndroZip™ FREE File Manager': 277794,
#  'Android Auto - Maps, Media, Messaging & Voice': 271920,
#  'Android Messages': 781810,
#  'Android P 9.0': 12,
#  'Android P Home KLWP': 0,
#  'Android P Launcher 9.0 launcher': 164,
#  'Android P Rotation': 502,
#  'Android P Stock Wallpapers': 16,
#  'Android P Style Icon Pack': 1,
#  'Android P Wallpapers': 53,
#  'Android P | Xperia™ Theme 4800+ icons': 29,
#  'Android TV Remote Service': 1,
#  'Android-P Mono Grey EMUI 8/5 Theme': 61,
#  'Angelcare AH': 0,
#  'Angelo Rules - Crazy day': 108336,
#  'Anger of stick 5 : zombie': 549039,
#  'Angry Birds 2': 3883589,
#  'Angry Birds Blast': 253115,
#  'Angry Birds Classic': 5566908,
#  'Angry Birds Epic RPG': 2634605,
#  'Angry Birds Evolution': 384602,
#  'Angry Birds Friends': 829753,
#  'Angry Birds Go!': 3846378,
#  'Angry Birds Match': 227401,
#  'Angry Birds POP Bubble Shooter': 596628,
#  'Angry Birds Rio': 2610680,
#  'Angry Birds Space HD': 43645,
#  'Angry Birds Star Wars': 1218055,
#  'Angry Shark 2016': 73185,
#  'Animal Hunting: Sniper Shooting': 0,
#  'Animal Jam - Play Wild!': 361970,
#  'Animal Planet GO': 2442,
#  'Animated Photo Editor': 203,
#  'Anime Avatar Creator: Make Your Own Avatar': 10944,
#  'Anime Expo 2018': 54,
#  'Anime Love Story Games: ✨Shadowtime✨': 198480,
#  'Anime Manga Coloring Book': 5035,
#  'Anime Mod for BM': 0,
#  'Anime X Wallpaper': 32613,
#  'Anime et Manga Amino en Français': 3782,
#  'Ankle Surgery ER Emergency': 10449,
#  'Anna.K Tarot': 17,
#  'Anno: Build an Empire': 33944,
#  'Annonces.ci': 14,
#  'Anonymous caller detection': 161,
#  'Ant Smasher by Best Cool & Fun Games': 1185148,
#  'Antenna Tool': 522,
#  'Antenna Tool Premium': 14,
#  'AntennaPict β': 15439,
#  'Anthem Anywhere': 2657,
#  'Anthem BC Anywhere': 496,
#  'Anti Adware': 18751,
#  'Anti Mosquito simulation': 74,
#  'Anti-virus Dr.Web Light': 1094094,
#  'Antillean Gold Telegram (original version)': 2939,
#  'Antivirus & Mobile Security': 351267,
#  'Any.do: To-do list, Calendar, Reminders & Planner': 298854,
#  'Ao Oni2': 21223,
#  'Ap Video Downloader for fb New 2018': 676,
#  'Apartment Decorating Ideas': 1478,
#  'Apartment List: Housing, Apt, and Property Rentals': 8481,
#  'Apartment, Home Rental Search: Realtor.com Rentals': 10117,
#  'Apartments & Rentals - Zillow': 27387,
#  'Apartments.com Rental Search': 22584,
#  'Apex Launcher': 266434,
#  'Apk Installer': 7750,
#  'App Lock: Locker w/ fingerprint, Parental Control': 37607,
#  'App Seguridad AV Villas': 251,
#  'App for Craigslist Pro - Buy & Sell Postings': 707,
#  'App vault': 25094,
#  'AppBrain Ad Detector': 9221,
#  'AppClose - The #1 FREE Co-Parenting App': 159,
#  'AppFinder by AppTap': 2221,
#  'AppLock': 4931562,
#  'AppLock - Fingerprint': 745245,
#  'AppLock - Fingerprint Unlock': 112482,
#  'Apple Daily Apple News': 41490,
#  'Applock': 4934130,
#  'Apps Ads Detector': 315,
#  'Apps for SportsBєtting.ag - Bitcoin Welcome here!': 0,
#  'Aproveita DF': 0,
#  'Aquarium Co-Op Podcast': 206,
#  'Aqw&3d Design Notes Manager': 11,
#  'Arab Halls - For Wedding & Events': 28,
#  'Arabic Alif Ba Ta For Kids': 226,
#  'Arabic Alphabet Alif Ba Ta Wooden Blocks': 66,
#  'Arabic Alphabets': 34,
#  'Arabic Chat - Chat': 162,
#  "Arby's": 194,
#  'Archery Physics Objects Destruction Apple shooter': 6026,
#  'Archie Comics': 5084,
#  'Archos File Manager': 2131,
#  'Arcraft - AR Sandbox': 469,
#  'Arena of Valor: 5v5 Arena Game': 438911,
#  'Ariana News AF': 20,
#  'Arizona DMV Permit Test - AZ': 109,
#  'Arizona Mobile': 285,
#  'Arizona Statutes, ARS (AZ Law)': 9,
#  'Arizona Trail': 65,
#  'Armani Exchange Connected': 305,
#  'Armed Cam Gun Pack': 1012,
#  'Armored Warfare: Assault': 7718,
#  'Army of Heroes': 85015,
#  'Arogyam EH': 18,
#  'Arrayanes EC': 2,
#  'Arrhythmias and Dysrhythmias': 3,
#  'Arrow.io': 343263,
#  'Arrowhead AH App': 3,
#  'Art Drawing Ideas': 227,
#  'Art Pixel Coloring. Color by Number.': 992,
#  'Art of F J Taylor': 2,
#  'Artificial Intelligence': 339,
#  'Artificial intelligence': 3,
#  'Arto: f.infrared photo': 41,
#  'Asahi Shimbun Digital': 735,
#  'Asana: organize team projects': 20815,
#  'Ascape VR: 360° Virtual Travel': 890,
#  'Asha Ek Hope - ALS/ MND': 2,
#  'Asiimov Skin - CS GO Icon Pack': 26,
#  'Asphalt 8: Airborne': 8389714,
#  'Asphalt Xtreme: Rally Racing': 567984,
#  "Assassin's Creed Identity": 42529,
#  'Assault Line CS Online Fps Go': 52163,
#  'Assemblr - Create 3D Models (Sandbox AR)': 1745,
#  'Associated Credit Union Mobile': 3290,
#  'Aster DM Healthcare': 32,
#  'Asteroids 3D live wallpaper': 157495,
#  'Asylum Night Shift - Five Nights Survival': 59223,
#  'At home - rental · real estate · room finding application such as apartment · apartment': 2496,
#  'Atlan3D Navigation: Korea navigator': 22063,
#  'Atlanta United FC': 215,
#  'Attack the Light': 19209,
#  'Au Bon Pain': 70,
#  'Au Mobile: Audition Chính Hiệu': 85278,
#  'Au Pair': 58,
#  'Au Pair Legend': 28,
#  'Au Rubis les bijoutiers': 0,
#  'Au Weather Free': 1185,
#  'Au-allstar for KR': 2433,
#  'Auction Wars : Storage King': 29062,
#  'Audio Murli Glossary For BK': 39,
#  'AudioBT: BT audio GPS/SMS/Text': 198,
#  'Audiobooks from Audible': 568922,
#  'Audiowalk EB': 0,
#  'Augment - 3D Augmented Reality': 25195,
#  'Aunjai i lert u': 1140,
#  'Aura Hair Group BC': 0,
#  'Aurum Blade EX': 28151,
#  'Australia Newspapers - AU News Apps': 48,
#  'Austria Wien FK - Fussball - Inoffizielle App': 2,
#  'Authy 2-Factor Authentication': 15070,
#  'Auto Background Changer': 35188,
#  'Auto DM for Twitter 🔥': 44,
#  'Auto Dslr Photo Effect : Auto Focus Effect': 6,
#  'AutoCAD - DWG Viewer & Editor': 145088,
#  'AutoScout24 - used car finder': 186648,
#  'AutoScout24 Switzerland – Find your new car': 13372,
#  'Automagic * Automation': 1947,
#  'Automatic Call Recorder': 1648515,
#  'Autool BT-BOX': 4,
#  'Autoroute.EU': 10,
#  'Avakin Life - 3D virtual world': 1275373,
#  'Avast Cleanup & Boost, Phone Cleaner, Optimizer': 648380,
#  'Avast Mobile Security 2018 - Antivirus & App Lock': 5180480,
#  'Avast Wi-Fi Finder': 37277,
#  'Avatar Musik': 159063,
#  'Avaya CX': 21,
#  'Avenger Legends': 3715,
#  'Aviary Effects: Classic': 67007,
#  'Aviary Stickers: Free Pack': 126862,
#  'Avios for Android': 862,
#  'Avokiddo Emotions': 73,
#  'Aw Restaurant': 4,
#  'Awake Dating': 2,
#  'Ax 3 Domaines': 12,
#  'Axe': 18,
#  'Axe Champ': 141,
#  'Axe Champ Hit': 1,
#  'Axe Champion': 21,
#  'Axe Champs! Wars': 8,
#  'Axe Clicker': 10446,
#  'Axe Knight': 52,
#  'Axe Man': 53,
#  'Axe Spinner': 2,
#  'Axe Throw: Flip Champ Axes Champion Throwing Games': 1,
#  'Axe Wallpaper': 9,
#  'Axetatic - Axe Throwing Game': 29,
#  'Axxess AX-DSP': 17,
#  'Axxess Updater': 56,
#  'Ay': 11,
#  'Ay Hasnain k Nana Milad Naat': 72,
#  'Ay Mohabbat Teri Khatir Novel': 27,
#  'Ay Peruk': 0,
#  'Ay Sabz Gunbad Waly': 4,
#  'Ay Telekom Oim': 6,
#  'Ay Up': 11,
#  'Ay Vamos - PJ. Balvin - Piano': 0,
#  'Ay Yıldız - Xperia Live Theme': 0,
#  'Ay Yıldız Analog Saat': 37,
#  'Ay Yıldız Duvar Kağıtları': 3,
#  'Ay Yıldız Keyboard': 26,
#  'Ayat - Al Quran': 173394,
#  'Ayyush wih wih new without Net': 912,
#  'Az Content': 24,
#  'Az Video Status': 13,
#  'AzadBazar.af': 3,
#  'Azar': 1092337,
#  'Azpen eReader': 156,
#  'Azulones Getafe CF Fans': 4,
#  'AÖF Ev İdaresi 1. Sınıf': 2,
#  'B': 800,
#  'B & W Filter for Photo Editor Pro': 65,
#  'B L Enterprises': 2,
#  'B R COACHINGS': 1,
#  'B R Telco FCU Mobile Banking': 413,
#  'B Tiff Viewer': 283,
#  'B y H Niños ES': 53,
#  'B&H Kids AR': 286,
#  'B&H Photo Video Pro Audio': 17180,
#  'B&M Stores': 192,
#  'B&W Photo Filter Editor': 205,
#  "B'H BURGER HEIM": 0,
#  'B-17 Flying Fortress WWII LWP': 7,
#  'B-52 Spirits of Glory Deluxe': 12,
#  'B-BLE(BLE4.0 Scan)': 159,
#  'B-Dubs®': 3042,
#  'B-Grade Renegade': 24,
#  'B-L Animal Hospital': 1,
#  'B-Messenger Video Chat': 12495,
#  'B. R. Ambedkar Jayanti SMS': 0,
#  'B.GOOD': 155,
#  'B.M.Snowboard Free': 9765,
#  'B.T.': 636,
#  'B.Z. Live-Ticker': 114,
#  'B612 - Beauty & Filter Camera': 5282578,
#  'B@dL!bs Lite': 10,
#  'BA 3 Banjarmasin': 2,
#  'BA Accesible': 31,
#  'BA Calculator': 22,
#  'BA Pro Financial Calculator': 36,
#  'BA SALES': 0,
#  'BA Status': 0,
#  'BA VPN - Free Unlimited VPN': 181,
#  'BA4You': 87,
#  'BAC DZ Questionnaire': 38,
#  'BAMMS for BM 1Park': 7,
#  'BAMMS for BM SQ': 2,
#  'BANGLA TV 3G/4G': 142,
#  'BAR-B-Q Recipes': 0,
#  'BBC Media Player': 87384,
#  'BBC News': 296781,
#  'BBC Persian | BBC Farsi News': 978,
#  'BBC Sport': 18679,
#  'BBM - Free Calls & Messages': 12843436,
#  'BBMoji - Your personalized BBM Stickers': 8827,
#  'BBVA Compass Banking': 5905,
#  'BBVA Spain': 36746,
#  'BBW Dating & Curvy Singles Chat- LargeFriends': 218,
#  'BBW Dating & Plus Size Chat': 12633,
#  'BBWCupid - BBW Dating App': 241,
#  'BC Camera': 5,
#  'BC Connect': 11,
#  'BC Highways - Road Conditions': 382,
#  'BC Hockey': 20,
#  'BC Hospital Wait Times': 8,
#  'BC Liquor Stores': 492,
#  'BC Lotto Check': 10,
#  'BC MVA Fines': 5,
#  'BC Mobile Intro - Americas': 0,
#  'BC Navigator': 21,
#  'BC Pizza': 3,
#  'BC Slots - The Lost Reels FREE': 209,
#  'BC Wildfire': 27,
#  'BC Wildflowers': 7,
#  'BC browser': 1,
#  'BC iptv player': 8,
#  "BC's Pizza": 113,
#  'BD All Results': 205,
#  'BD All Sim Offer': 197,
#  'BD Attendance': 93,
#  'BD Bank Interest': 289,
#  'BD Briight: Your Diabetes Personal Assistant': 17,
#  'BD CRICKET LIVE': 1238,
#  'BD Data Plan (3G & 4G)': 10341,
#  'BD Dialer': 29,
#  'BD Earn Pro': 540,
#  'BD Field Force': 41,
#  ...}

# %% [markdown]
# **4**. Các app bị lưu nhiều lần mình chỉ giữ lại 1 app có số lượng reviews nhiều nhất, boolean mask

# %%
data.loc[data.groupby(['App'])['Reviews'].idxmax()]
# Out:
#                                                    App       Category Rating  \
# 8884              "i DT" Fútbol. Todos Somos Técnicos.         SPORTS    NaN
# 8532                     +Download 4 Instagram Twitter         SOCIAL    4.5
# 324                         - Free Comics - Comic Apps         COMICS    3.5
# 4541                                                .R          TOOLS    4.5
# 4636                                            /u/app  COMMUNICATION    4.7
# ...                                                ...            ...    ...
# 6334                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS    NaN
# 4362                                        💎 I'm rich      LIFESTYLE    3.8
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL    4.6
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS    4.0
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT    4.7
#
#       Reviews  Size    Installs  Type    Price Content Rating  \
# 8884       27  3.6M        500+  Free        0       Everyone
# 8532    40467   22M  1,000,000+  Free        0       Everyone
# 324       115  9.1M     10,000+  Free        0     Mature 17+
# 4541      259  203k     10,000+  Free        0       Everyone
# 4636      573   53M     10,000+  Free        0     Mature 17+
# ...       ...   ...         ...   ...      ...            ...
# 6334      414   59M    100,000+  Free        0     Mature 17+
# 4362      718   26M     10,000+  Paid  $399.99       Everyone
# 2575    22098   18M  1,000,000+  Free        0       Everyone
# 7559       19  3.2M     10,000+  Free        0       Everyone
# 882     11661  4.0M  1,000,000+  Free        0       Everyone
#
#                        Genres        Last Updated Current Ver   Android Ver
# 8884                   Sports     October 7, 2017        0.22    4.1 and up
# 8532                   Social      August 2, 2018        5.03    4.1 and up
# 324                    Comics       July 13, 2018      5.0.12    5.0 and up
# 4541                    Tools  September 16, 2014      1.1.06    1.5 and up
# 4636            Communication        July 3, 2018       4.2.4    4.1 and up
# ...                       ...                 ...         ...           ...
# 6334  Video Players & Editors       July 18, 2018       4.0.7  4.0.3 and up
# 4362                Lifestyle      March 11, 2018       1.0.0    4.4 and up
# 2575                   Social       July 24, 2018       4.2.4  4.0.3 and up
# 7559                    Tools    October 21, 2017         1.0    4.2 and up
# 882             Entertainment       July 14, 2018     1.1.3.2  4.0.3 and up
#
# [9660 rows x 13 columns]

# %% [markdown]
# **5.** Mình quan tâm đến các app tiếng anh, nên sẽ lọc các app có tên bằng tiếng anh.
# - Viết hàm kiểm tra tên app: checkEnglishName(name).
# - Hàm trả về True nếu tên app có tối đa 3 kí tự ascii không nằm trong khoảng (0-127).
# - Chấp nhận 3 kí tự nằm ngoài khoảng 0-127 vì có những app có tên gồm kí tự emoji như: "Instachat 😜"
# - Sau đó lọc các app có tên thỏa mãn hàm checkEnglishName, (map, apply)

# %%
def is_ascii(s):
  cnt=0
  for c in s:
    if ord(c) > 128: cnt+=1 
  if cnt > 3: return False
  else: return True

# %%
data.App.apply(lambda x: is_ascii(x))
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: App, Length: 10841, dtype: bool

# %%
data.App.loc[data.App.apply(lambda x: is_ascii(x))]
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10796, dtype: object

# %% [markdown]
# **6.** Mình quan tâm đến các app free, lọc các app có Type='Free', data[data.Type=='Free']

# %%
data[data.Type=='Free'].App
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10040, dtype: object

# %% [markdown]
# **7.** Mình muốn xem trong các app free, tổng số lượng app của mỗi category Series(value_counts, unique) là bao nhiêu. Sau đó tính tần suất xuất hiện của mỗi category. Rồi trả lời các câu hỏi:
# - Category nào phổ biến nhất? Category nào có ít app nhất.
# - Xu hướng app làm về các category như thế nào.

# %%
free = data[data.Type=='Free']
free.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
cat = free.Category.value_counts()
cat
# Out:
# FAMILY                 1780
# GAME                   1061
# TOOLS                   766
# BUSINESS                446
# PRODUCTIVITY            396
# LIFESTYLE               363
# COMMUNICATION           360
# SPORTS                  360
# MEDICAL                 354
# FINANCE                 349
# HEALTH_AND_FITNESS      325
# PHOTOGRAPHY             313
# PERSONALIZATION         309
# SOCIAL                  292
# NEWS_AND_MAGAZINES      281
# SHOPPING                258
# TRAVEL_AND_LOCAL        246
# DATING                  227
# BOOKS_AND_REFERENCE     203
# VIDEO_PLAYERS           171
# EDUCATION               152
# ENTERTAINMENT           147
# MAPS_AND_NAVIGATION     132
# FOOD_AND_DRINK          125
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       84
# AUTO_AND_VEHICLES        82
# WEATHER                  74
# EVENTS                   63
# ART_AND_DESIGN           62
# COMICS                   60
# PARENTING                58
# BEAUTY                   53
# Name: Category, dtype: int64

# %%
cat.idxmax()
# Out:
# 'FAMILY'

# %%
cat.idxmin()
# Out:
# 'BEAUTY'

# %% [markdown]
# **8.** Tính độ rating trung bình ở mỗi category (groupby)

# %%
data.Rating = data.Rating.astype(float)

# %%
data.groupby(['Category']).Rating.mean()
# Out:
# Category
# ART_AND_DESIGN         4.358065
# AUTO_AND_VEHICLES      4.190411
# BEAUTY                 4.278571
# BOOKS_AND_REFERENCE    4.346067
# BUSINESS               4.121452
# COMICS                 4.155172
# COMMUNICATION          4.158537
# DATING                 3.970769
# EDUCATION              4.389032
# ENTERTAINMENT          4.126174
# EVENTS                 4.435556
# FAMILY                 4.192272
# FINANCE                4.131889
# FOOD_AND_DRINK         4.166972
# GAME                   4.286326
# HEALTH_AND_FITNESS     4.277104
# HOUSE_AND_HOME         4.197368
# LIBRARIES_AND_DEMO     4.178462
# LIFESTYLE              4.094904
# MAPS_AND_NAVIGATION    4.051613
# MEDICAL                4.189143
# NEWS_AND_MAGAZINES     4.132189
# PARENTING              4.300000
# PERSONALIZATION        4.335987
# PHOTOGRAPHY            4.192114
# PRODUCTIVITY           4.211396
# SHOPPING               4.259664
# SOCIAL                 4.255598
# SPORTS                 4.223511
# TOOLS                  4.044490
# TRAVEL_AND_LOCAL       4.109292
# VIDEO_PLAYERS          4.063750
# WEATHER                4.244000
# Name: Rating, dtype: float64

# %% [markdown]
# **9.** Trường số lượng Install đang ở dạng string, do có dấu "," và "+", xử lý đưa về dạng số.
# - Tính số lượng Install trung bình ở mỗi category.

# %%
data.Installs = data.Installs.apply(lambda x: x.strip('+,').replace(r',', '')).astype(int)

# %%
data.groupby(['Category']).Installs.mean()
# Out:
# Category
# ART_AND_DESIGN         1.912894e+06
# AUTO_AND_VEHICLES      6.250613e+05
# BEAUTY                 5.131519e+05
# BOOKS_AND_REFERENCE    8.318050e+06
# BUSINESS               2.178076e+06
# COMICS                 9.347692e+05
# COMMUNICATION          8.435989e+07
# DATING                 1.129533e+06
# EDUCATION              5.586231e+06
# ENTERTAINMENT          1.925611e+07
# EVENTS                 2.495806e+05
# FAMILY                 5.201959e+06
# FINANCE                2.395215e+06
# FOOD_AND_DRINK         2.156683e+06
# GAME                   3.066960e+07
# HEALTH_AND_FITNESS     4.642441e+06
# HOUSE_AND_HOME         1.917187e+06
# LIBRARIES_AND_DEMO     7.411284e+05
# LIFESTYLE              1.407444e+06
# MAPS_AND_NAVIGATION    5.286729e+06
# MEDICAL                1.150269e+05
# NEWS_AND_MAGAZINES     2.648876e+07
# PARENTING              5.253518e+05
# PERSONALIZATION        5.932385e+06
# PHOTOGRAPHY            3.011417e+07
# PRODUCTIVITY           3.343418e+07
# SHOPPING               1.249173e+07
# SOCIAL                 4.769447e+07
# SPORTS                 4.560350e+06
# TOOLS                  1.356964e+07
# TRAVEL_AND_LOCAL       2.662359e+07
# VIDEO_PLAYERS          3.555430e+07
# WEATHER                5.196348e+06
# Name: Installs, dtype: float64

# %% [markdown]
# **10.** Category nào sẽ potential nếu mình muốn làm app free và kiếm tiền dựa vào quảng cáo.

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating  Reviews                Size     Installs  Type Price  \
# 0        4.1      159                 19M      10,000+  Free     0
# 1        3.9      967                 14M     500,000+  Free     0
# 2        4.7    87510                8.7M   5,000,000+  Free     0
# 3        4.5   215644                 25M  50,000,000+  Free     0
# 4        4.3      967                2.8M     100,000+  Free     0
# ...      ...      ...                 ...          ...   ...   ...
# 10836    4.5       38                 53M       5,000+  Free     0
# 10837    5.0        4                3.6M         100+  Free     0
# 10838    NaN        3                9.5M       1,000+  Free     0
# 10839    4.5      114  Varies with device       1,000+  Free     0
# 10840    4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
# data['Type']
data.Type.value_counts()
# Out:
# Free    10040
# Paid      800
# NaN         1
# Name: Type, dtype: int64

# %%
free[free.Installs==free.Installs.max()]
# Out:
#                                                     App            Category  \
# 342                                     Viber Messenger       COMMUNICATION
# 347                       imo free video calls and chat       COMMUNICATION
# 371               Google Duo - High Quality Video Calls       COMMUNICATION
# 378         UC Browser - Fast Download Private & Secure       COMMUNICATION
# 383                       imo free video calls and chat       COMMUNICATION
# ...                                                 ...                 ...
# 4365                                          MX Player       VIDEO_PLAYERS
# 4566                         SHAREit - Transfer & Share               TOOLS
# 4676                                    Viber Messenger       COMMUNICATION
# 5596                                     Samsung Health  HEALTH_AND_FITNESS
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
#
#      Rating   Reviews                Size      Installs  Type Price  \
# 342     4.3  11334799  Varies with device  500,000,000+  Free     0
# 347     4.3   4785892                 11M  500,000,000+  Free     0
# 371     4.6   2083237  Varies with device  500,000,000+  Free     0
# 378     4.5  17712922                 40M  500,000,000+  Free     0
# 383     4.3   4785988                 11M  500,000,000+  Free     0
# ...     ...       ...                 ...           ...   ...   ...
# 4365    4.5   6469179  Varies with device  500,000,000+  Free     0
# 4566    4.6   7775146                 17M  500,000,000+  Free     0
# 4676    4.3  11335481  Varies with device  500,000,000+  Free     0
# 5596    4.3    480208                 70M  500,000,000+  Free     0
# 7536    4.7  24900999  Varies with device  500,000,000+  Free     0
#
#      Content Rating                   Genres    Last Updated  \
# 342        Everyone            Communication   July 18, 2018
# 347        Everyone            Communication    June 8, 2018
# 371        Everyone            Communication   July 31, 2018
# 378            Teen            Communication  August 2, 2018
# 383        Everyone            Communication    June 8, 2018
# ...             ...                      ...             ...
# 4365       Everyone  Video Players & Editors  August 1, 2018
# 4566       Everyone                    Tools   July 30, 2018
# 4676       Everyone            Communication   July 18, 2018
# 5596       Everyone         Health & Fitness   July 31, 2018
# 7536       Everyone                    Tools  August 4, 2018
#
#                    Current Ver         Android Ver
# 342         Varies with device  Varies with device
# 347           9.8.000000010501          4.0 and up
# 371   37.1.206017801.DR37_RC14          4.4 and up
# 378                12.8.5.1121          4.0 and up
# 383           9.8.000000010501          4.0 and up
# ...                        ...                 ...
# 4365        Varies with device  Varies with device
# 4566                 4.5.28_ww          4.1 and up
# 4676        Varies with device  Varies with device
# 5596                5.17.2.009          5.0 and up
# 7536                     4.6.6  Varies with device
#
# [72 rows x 13 columns]

# %%
free.Installs = free.Installs.apply(lambda x: x.strip('+,').replace(r',', '')).astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
free.groupby(['Category']).Installs.sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   35064924450
# COMMUNICATION          32645916201
# PRODUCTIVITY           14174679314
# SOCIAL                 14069861902
# TOOLS                  11451045474
# FAMILY                 10226991691
# PHOTOGRAPHY            10084268915
# NEWS_AND_MAGAZINES      7496312260
# TRAVEL_AND_LOCAL        6868704086
# VIDEO_PLAYERS           6221931720
# SHOPPING                3247838685
# ENTERTAINMENT           2868960000
# PERSONALIZATION         2320235988
# BOOKS_AND_REFERENCE     1921446260
# SPORTS                  1749930683
# HEALTH_AND_FITNESS      1582498402
# BUSINESS                1001502090
# FINANCE                  876463132
# EDUCATION                870850000
# MAPS_AND_NAVIGATION      724160790
# LIFESTYLE                536464429
# WEATHER                  425288520
# FOOD_AND_DRINK           273838751
# DATING                   264289457
# HOUSE_AND_HOME           168712461
# ART_AND_DESIGN           124322100
# LIBRARIES_AND_DEMO        62995810
# COMICS                    56086150
# AUTO_AND_VEHICLES         53080061
# MEDICAL                   52237404
# PARENTING                 31471010
# BEAUTY                    27197050
# EVENTS                    15973160
# Name: Installs, dtype: int64

# %%
free.groupby(['Category']).Installs.sum().idxmax()
# Out:
# 'GAME'
